# %% [markdown]
# ## Project CodeAlpha_HandwrittenCharacterRecognition

# %% [markdown]
# **Reasoning**:
# Importing all necessary libraries and setting global visual parameters for the project.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, precision_recall_curve
import os

# Set plotting aesthetics
sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams.update({
    'figure.figsize': (10, 6),
    'axes.titlesize': 16,
    'axes.labelsize': 14,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'legend.fontsize': 12
})

print(f'TensorFlow version: {tf.__version__}')
print('Environment setup complete.')

# %%
# Load the MNIST dataset
print('Loading MNIST dataset...')
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Data Profiling
print(f'Training images shape: {x_train.shape}')
print(f'Training labels shape: {y_train.shape}')
print(f'Testing images shape: {x_test.shape}')
print(f'Testing labels shape: {y_test.shape}')

# Check unique classes and data types
unique_labels = np.unique(y_train)
print(f'Unique labels: {unique_labels}')
print(f'Number of classes: {len(unique_labels)}')
print(f'Image data type: {x_train.dtype}')
print(f'Label data type: {y_train.dtype}')

# Quick check on a single pixel range
print(f'Pixel value range: {x_train.min()} to {x_train.max()}')
